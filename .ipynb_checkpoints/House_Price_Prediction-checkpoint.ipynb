# %% [markdown]
# ### Importing The Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
import xgboost as xgb
import joblib

# %% [markdown]
# ## Working On The Training Data

# %% [markdown]
# ## Reading the Data

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
for data in train_data.columns:
    print(train_data[data].unique())
# Out:
# [   1    2    3 ... 1458 1459 1460]
# [ 60  20  70  50 190  45  90 120  30  85  80 160  75 180  40]
# ['RL' 'RM' 'C (all)' 'FV' 'RH']
# [ 65.  80.  68.  60.  84.  85.  75.  nan  51.  50.  70.  91.  72.  66.
#  101.  57.  44. 110.  98.  47. 108. 112.  74. 115.  61.  48.  33.  52.
#  100.  24.  89.  63.  76.  81.  95.  69.  21.  32.  78. 121. 122.  40.
#  105.  73.  77.  64.  94.  34.  90.  55.  88.  82.  71. 120. 107.  92.
#  134.  62.  86. 141.  97.  54.  41.  79. 174.  99.  67.  83.  43. 103.
#   93.  30. 129. 140.  35.  37. 118.  87. 116. 150. 111.  49.  96.  59.
#   36.  56. 102.  58.  38. 109. 130.  53. 137.  45. 106. 104.  42.  39.
#  144. 114. 128. 149. 313. 168. 182. 138. 160. 152. 124. 153.  46.]
# [ 8450  9600 11250 ... 17217 13175  9717]
# ['Pave' 'Grvl']
# [nan 'Grvl' 'Pave']
# ['Reg' 'IR1' 'IR2' 'IR3']
# ['Lvl' 'Bnk' 'Low' 'HLS']
# ['AllPub' 'NoSeWa']
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# ['Gtl' 'Mod' 'Sev']
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
train_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train_data.shape
# Out:
# (1460, 81)

# %%
train_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# ## Handling The LotFrontage column missing values On both the training & Testing Set

# %% [markdown]
# ## Train

# %%
train_data['LotFrontage'].unique()
# Out:
# array([ 65.,  80.,  68.,  60.,  84.,  85.,  75.,  nan,  51.,  50.,  70.,
#         91.,  72.,  66., 101.,  57.,  44., 110.,  98.,  47., 108., 112.,
#         74., 115.,  61.,  48.,  33.,  52., 100.,  24.,  89.,  63.,  76.,
#         81.,  95.,  69.,  21.,  32.,  78., 121., 122.,  40., 105.,  73.,
#         77.,  64.,  94.,  34.,  90.,  55.,  88.,  82.,  71., 120., 107.,
#         92., 134.,  62.,  86., 141.,  97.,  54.,  41.,  79., 174.,  99.,
#         67.,  83.,  43., 103.,  93.,  30., 129., 140.,  35.,  37., 118.,
#         87., 116., 150., 111.,  49.,  96.,  59.,  36.,  56., 102.,  58.,
#         38., 109., 130.,  53., 137.,  45., 106., 104.,  42.,  39., 144.,
#        114., 128., 149., 313., 168., 182., 138., 160., 152., 124., 153.,
#         46.])

# %%
train_data['LotFrontage'] = train_data['LotFrontage'].replace(np.nan, 0)
mean = train_data['LotFrontage'].mean()
train_data['LotFrontage'] = train_data['LotFrontage'].replace(0, mean)

# %%
train_data['LotFrontage'].dtype
# Out:
# dtype('float64')

# %%
train_data['LotFrontage'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Test

# %%
test_data['LotFrontage'].unique()
# Out:
# array([ 80.,  81.,  74.,  78.,  43.,  75.,  nan,  63.,  85.,  70.,  26.,
#         21.,  24., 102.,  94.,  90.,  79., 110., 105.,  41., 100.,  67.,
#         60.,  73.,  92.,  84.,  39.,  88.,  25.,  30.,  57.,  68.,  98.,
#        120.,  87., 119.,  65.,  56.,  69.,  50.,  53.,  52.,  51.,  72.,
#         86., 124.,  44.,  83.,  64.,  82.,  38.,  89.,  35.,  58.,  66.,
#         93.,  31.,  76.,  28.,  61.,  95., 129.,  59.,  77.,  96.,  47.,
#         34., 117.,  48.,  62.,  42., 106., 112.,  32., 115.,  71.,  45.,
#        109., 113., 125., 101., 104., 108., 130., 135.,  36.,  55., 136.,
#         97.,  91.,  37.,  22., 103.,  99.,  40., 123.,  54., 107., 150.,
#        160., 195., 128.,  33., 118., 134., 155., 126.,  46., 149., 200.,
#        121., 131., 114.,  49., 133., 140.])

# %%
test_data['LotFrontage'].isnull().sum()
# Out:
# 227

# %%
test_data['LotFrontage'] = test_data['LotFrontage'].replace(np.nan, 0)
mean = test_data['LotFrontage'].mean()
test_data['LotFrontage'] = test_data['LotFrontage'].replace(0, mean)

# %%
train_data['LotFrontage'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Replacing The Nan Values In The Alley Column with None in both Training & Testing Set
#
# #### NOTE : They are not NULL values, They are recorded to be None

# %% [markdown]
# ### Train Set

# %%
train_data['Alley'] = train_data['Alley'].replace(np.nan, 'None')

# %%
train_data['Alley'].unique()
# Out:
# array(['None', 'Grvl', 'Pave'], dtype=object)

# %% [markdown]
# ### Test Set

# %%
test_data['Alley'] = test_data['Alley'].replace(np.nan, 'None')

# %%
test_data['Alley'].unique()
# Out:
# array(['None', 'Pave', 'Grvl'], dtype=object)

# %%
test_data['Alley'].isnull().sum()
# Out:
# 0

# %%
test_data['Utilities'].unique()
# Out:
# array(['AllPub', nan], dtype=object)

# %% [markdown]
# ## Replacing The Nan Values in The Utilities Column with None in the testing Set

# %%
test_data['Utilities'] = test_data['Utilities'].replace(np.nan, 'None')

# %%
test_data['Utilities'].unique()
# Out:
# array(['AllPub', 'None'], dtype=object)

# %% [markdown]
# ## Replacing The Missing Values of The " MasVnrArea " column with THe mean On both the training & the testing set

# %% [markdown]
# ### Train

# %%
train_data['MasVnrArea'] = train_data['MasVnrArea'].replace(np.nan, 0)

# %%
mean = train_data['MasVnrArea'].mean()
train_data['MasVnrArea'] = train_data['MasVnrArea'].replace(0, mean)

# %%
train_data['MasVnrArea'].head()
# Out:
# 0    196.000000
# 1    103.117123
# 2    162.000000
# 3    103.117123
# 4    350.000000
# Name: MasVnrArea, dtype: float64

# %% [markdown]
# ### Test

# %%
test_data['MasVnrArea'] = test_data['MasVnrArea'].replace(np.nan, 0)

# %%
mean = test_data['MasVnrArea'].mean()
test_data['MasVnrArea'] = test_data['MasVnrArea'].replace(0, mean)

# %%
test_data['MasVnrArea'].head()
# Out:
# 0     99.673749
# 1    108.000000
# 2     99.673749
# 3     20.000000
# 4     99.673749
# Name: MasVnrArea, dtype: float64

# %% [markdown]
# ## Replacing Column with Nan with None in both training and testing Set

# %% [markdown]
# ### Training Set

# %%
cols = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']

# %%
for col in train_data[cols]:
    train_data[col] = train_data[col].replace(np.nan, 'None')

# %%
train_data[col].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Testing Set

# %%
cols = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']

# %%
for col in test_data[cols]:
    test_data[col] = test_data[col].replace(np.nan, 'None')

# %%
test_data[col].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Replacing Values of the Columns below with their mode and also converting them to an Integer onThe Training and Testing Set

# %% [markdown]
# ### Testing Set

# %%
cols = ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt', 'GarageCars', 'GarageArea']

# %%
for col in test_data[cols]:
#     test_data[col] = test_data[col].replace(np.nan, 0)
    mode = test_data[col].mode()[0]
    test_data[col].fillna(mode, inplace=True)
    test_data[col] = test_data[col].astype(int)

# %%
test_data[col].dtypes
# Out:
# dtype('int32')

# %%
test_data['GarageYrBlt'].head()
# Out:
# 0    1961
# 1    1958
# 2    1997
# 3    1998
# 4    1992
# Name: GarageYrBlt, dtype: int32

# %% [markdown]
# ## Training Set

# %%
mode = train_data['GarageYrBlt'].mode()[0]
train_data['GarageYrBlt'].fillna(mode, inplace=True)

# %%
train_data['GarageYrBlt'] = train_data['GarageYrBlt'].astype(int)

# %%
train_data['GarageYrBlt'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# ## Replacing The " CentralAir " Column values (Y & N) with (1 & 0) respectively both in the training and testing Set

# %% [markdown]
# ### Training Set

# %%
train_data['CentralAir'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
train_data['CentralAir'] = train_data['CentralAir'].replace('N',0)
train_data['CentralAir'] = train_data['CentralAir'].replace('Y',1)

# %%
train_data['CentralAir'].unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# ### Testing Set

# %%
test_data['CentralAir'] = test_data['CentralAir'].replace('N',0)
test_data['CentralAir'] = test_data['CentralAir'].replace('Y',1)

# %%
test_data['CentralAir'].unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# ## Replacing The Missing Values in the Training & Testing set Columns with the mode

# %% [markdown]
# ### Training Set

# %%
# train_data['Electrical'] = train_data['Electrical'].replace(np.nan, 0)
mode = train_data['Electrical'].mode()[0]
train_data['Electrical'].fillna(mode, inplace=True)

# %%
train_data['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix'], dtype=object)

# %%
train_data['Electrical'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Testing Set

# %%
mode = test_data['SaleType'].mode()[0]
test_data['SaleType'].fillna(mode, inplace=True)

# %%
test_data['SaleType'].head()
# Out:
# 0    WD
# 1    WD
# 2    WD
# 3    WD
# 4    WD
# Name: SaleType, dtype: object

# %% [markdown]
# ## Replacing Values of the Columns below with their mode On The training and testing set

# %% [markdown]
# ### Training Set

# %%
mode = train_data['MasVnrType'].mode()[0]
train_data['MasVnrType'].fillna(mode, inplace=True)

# %%
 train_data['MasVnrType'].unique()
# Out:
# array(['BrkFace', 'None', 'Stone', 'BrkCmn'], dtype=object)

# %%
 train_data['MasVnrType'].isnull().sum()
# Out:
# 0

# %%
cols = ['Exterior1st', 'Exterior2nd', 'KitchenQual','Functional', 'MSZoning', 'MasVnrType']

# %%
for col in test_data[cols]:
    mode = test_data[col].mode()[0]
    test_data[col].fillna(mode, inplace=True)

# %%
test_data[col].isnull().sum()
# Out:
# 0

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   object
#  3   LotFrontage    1459 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          1459 non-null   object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1459 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %% [markdown]
# ## Dropping Columns And Selecting Training set Features and Target Variables

# %% [markdown]
# #### Select Training Set

# %%
X_train = train_data.drop(['Id','SalePrice'], axis=1).copy()

# %%
y_train = train_data['SalePrice'].copy()

# %%
X_train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  None      Reg
# 1          20       RL         80.0     9600   Pave  None      Reg
# 2          60       RL         68.0    11250   Pave  None      IR1
# 3          70       RL         60.0     9550   Pave  None      IR1
# 4          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0   None  None
# 1         Lvl    AllPub       FR2  ...           0        0   None  None
# 2         Lvl    AllPub    Inside  ...           0        0   None  None
# 3         Lvl    AllPub    Corner  ...           0        0   None  None
# 4         Lvl    AllPub       FR2  ...           0        0   None  None
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
# X_train.head()

# %% [markdown]
# ### Selecting Testing set

# %%
X_test = test_data.drop('Id', axis=1).copy()

# %%
X_test.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          20       RH         80.0    11622   Pave  None      Reg
# 1          20       RL         81.0    14267   Pave  None      IR1
# 2          60       RL         74.0    13830   Pave  None      IR1
# 3          60       RL         78.0     9978   Pave  None      IR1
# 4         120       RL         43.0     5005   Pave  None      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub    Inside  ...         120        0   None  MnPrv
# 1         Lvl    AllPub    Corner  ...           0        0   None   None
# 2         Lvl    AllPub    Inside  ...           0        0   None  MnPrv
# 3         Lvl    AllPub    Inside  ...           0        0   None   None
# 4         HLS    AllPub    Inside  ...         144        0   None   None
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
plt.scatter(train_data['MSZoning'], train_data['SalePrice'])
plt.show()

# %% [markdown]
# ## Using Exploratory Data Analysis (EDA) to understand the pattern of the data as well as figuring out the outliers in the data

# %%
# cols = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'GarageType', 'GarageFinish', 'GarageQual','GarageCond', 'PoolQC', 'Fence','FireplaceQu', 'Alley']

# %%
for  data in X_train.columns:
    fig, ax = plt.subplots(figsize=(10,7))
    ax.scatter(x=X_train[data], y=y_train)
    plt.xticks(rotation=(45))
    plt.show()

# %%
for  data in X_train.columns:
    fig, ax = plt.subplots(figsize=(10,7))
    sns.boxplot(x=X_train[data], y=y_train)
    plt.xticks(rotation=(45))
    plt.show()

# %% [markdown]
# ## Encoding Columns with Categorical Values in Our data

# %%
# # Columns to be encoded
# train_encode_cols = ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'FireplaceQu', 'PavedDrive',
# 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'Heating', 'HeatingQC', 'MiscFeature', 'SaleType', 'SaleCondition',
# 'Electrical', 'KitchenQual', 'Functional', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'GarageType', 'GarageFinish', 'GarageQual','GarageCond', 'PoolQC', 'Fence', 'Alley']

# %%
train_encode_cols =  list(X_train.select_dtypes(include=['object']))

# %%
print(train_encode_cols)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
len(train_encode_cols)
# Out:
# 42

# %%
X_train_encoded = pd.get_dummies(X_train, columns=train_encode_cols)

# %%
X_train_encoded.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLw  \
# 0          2003  196.000000         706           0  ...               0
# 1          1976  103.117123         978           0  ...               0
# 2          2002  162.000000         486           0  ...               0
# 3          1970  103.117123         216           0  ...               0
# 4          2000  350.000000         655           0  ...               0
#
#    SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# ...

# %%
test_encode_cols =  list(X_test.select_dtypes(include=['object']))

# %%
len(test_encode_cols)
# Out:
# 42

# %%
print(test_encode_cols)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
X_test_encoded = pd.get_dummies(X_test, columns=test_encode_cols)

# %%
X_test_encoded.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          20         80.0    11622            5            6       1961
# 1          20         81.0    14267            6            6       1958
# 2          60         74.0    13830            5            5       1997
# 3          60         78.0     9978            6            6       1998
# 4         120         43.0     5005            8            5       1992
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLw  \
# 0          1961   99.673749         468         144  ...               0
# 1          1958  108.000000         923           0  ...               0
# 2          1998   99.673749         791           0  ...               0
# 3          1998   20.000000         602           0  ...               0
# 4          1992   99.673749         263           0  ...               0
#
#    SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# ...

# %% [markdown]
# ## Features Normalization

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_encoded)

# %%
X_test = scaler.fit_transform(X_test_encoded)

# %%
np.shape(X_train), np.shape(X_test)
# Out:
# ((1460, 301), (1459, 284))

# %% [markdown]
# ## Building Our Regression Model

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = regressor.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-897-dce077bf6c20> in <module>
# ----> 1 prediction = regressor.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     219
#     220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# --> 221         return safe_sparse_dot(X, self.coef_.T,
#     222                                dense_output=True) + self.intercept_
#     223
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...
